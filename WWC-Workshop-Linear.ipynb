# %% [markdown]
# # Zero to AI Hero ft. SageMaker
#
# Welcome to the WWC Connect 2019 SageMaker workshop!
#
# In this Notebook we are going to show you how to train and deploy a machine learning model on SageMaker.
#
# We will be looking at a breast-cancer dataset and using the linear learning algorithm to classify tumors as either malignant or benign.
#
# The dataset is historical and anonymized patient data from the US, which contains information on 10 different attributes of patient tumors.
#
# (classification 1= Benign, 2= Malignant)

# %%
import numpy as np
import pandas as pd

import boto3
import re

import sagemaker
from sagemaker import get_execution_role
from sklearn.preprocessing import LabelEncoder
from sagemaker.predictor import csv_serializer

# %% [markdown]
# ## Setting up your bucket
# Amazon Simple Storage Service(S3) provides object storage and is designed to make web-scale computing easier for developers.
#
# S3 allows users to store and retrieve any amount of data, at any time, from anywhere on the web. It gives any developer access to the same highly scalable, reliable, fast, inexpensive data storage infrastructure that Amazon uses to run its own global network of web sites. The service aims to maximize benefits of scale and to pass those benefits on to developers.
#
# For more info on s3 - https://docs.aws.amazon.com/AmazonS3/latest/dev/Welcome.html

# %%
# Specify your bucket name
bucket_name = 'udemy-workshop-chloe'

training_folder = r'wwc-workshop/data/'
validation_folder = r'wwc-workshop/validation/'
test_folder = r'wwc-workshop/validation/'

s3_model_output_location = r's3://{0}/wwc-workshop/model'.format(bucket_name)
s3_training_file_location = r's3://{0}/{1}'.format(bucket_name,training_folder)
s3_validation_file_location = r's3://{0}/{1}'.format(bucket_name,validation_folder)
s3_validation_file_location = r's3://{0}/{1}'.format(bucket_name,test_folder)

# %%
print(s3_model_output_location)
print(s3_training_file_location)
# Out:
# s3://udemy-workshop-chloe/wwc-workshop/model
# s3://udemy-workshop-chloe/wwc-workshop/data/

# %% [markdown]
# ## Data
# We have already pre-processed the data for this workshop and have split it into 3 files, which you have dowloaded:
# 1. training.csv
# 2. validation.csv
# 3. test.csv
#
# If you would like to see how we did this, the code can be found in the Data-cleaning.ipynb file.
# For SageMaker to use these files we need to move them into the S3 bucket that we have created using the following code.

# %%
# Write and Reading from S3 is just as easy
# files are referred as objects in S3.  
# file name is referred as key name in S3

# File stored in S3 is automatically replicated across 3 different availability zones 
# in the region where the bucket was created.

# http://boto3.readthedocs.io/en/latest/guide/s3.html
def write_to_s3(filename, bucket, key):
    with open(filename,'rb') as f: # Read in binary mode
        return boto3.Session().resource('s3').Bucket(bucket).Object(key).upload_fileobj(f)

# %%
write_to_s3('train.csv', 
            bucket_name,
            training_folder + 'train.csv')

# %%
write_to_s3('validation.csv',
            bucket_name,
            validation_folder + 'validation.csv')

# %%
write_to_s3('test.csv',
            bucket_name,
            test_folder + 'test.csv')

# %% [markdown]
# ## Training Algorithm Docker Image
# SageMaker maintains a separate image for algorithm and region
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# %%
# Establish a session with AWS
sess = sagemaker.Session()

# %%
role = get_execution_role()

# %%
# Sagemaker API now maintains the algorithm container mapping for us
# Specify the region, algorithm and version
container = sagemaker.amazon.amazon_estimator.get_image_uri(
    sess.boto_region_name,
    "linear-learner", 
    "latest")

print('Using SageMaker linear-learner container:\n{} ({})'.format(container, sess.boto_region_name))
# Out:
# Using SageMaker linear-learner container:
# 644912444149.dkr.ecr.eu-west-2.amazonaws.com/linear-learner:latest (eu-west-2)

# %%
# Configure the training job
# Specify type and number of instances to use
# S3 location where final artifacts needs to be stored

#   Reference: http://sagemaker.readthedocs.io/en/latest/estimators.html

estimator = sagemaker.estimator.Estimator(
    container,
    role, 
    train_instance_count=1, 
    train_instance_type='ml.m4.xlarge',
    output_path=s3_model_output_location,
    sagemaker_session=sess,
    base_job_name ='linear-workshop-v5-1')

# %%
estimator.set_hyperparameters(feature_dim=9,
                           predictor_type='binary_classifier',
                           mini_batch_size=200)

# %%
estimator.hyperparameters()
# Out:
# {'feature_dim': 9,
#  'predictor_type': 'binary_classifier',
#  'mini_batch_size': 200}

# %% [markdown]
# # Specify Training Data Location and Optionally, Validation Data Location

# %%
training_input_config = sagemaker.session.s3_input(
    s3_data=s3_training_file_location,
    content_type='text/csv',
    s3_data_type='S3Prefix')

validation_input_config = sagemaker.session.s3_input(
    s3_data=s3_validation_file_location,
    content_type='text/csv',
    s3_data_type='S3Prefix'
)

data_channels = {'train': training_input_config, 'validation': validation_input_config}

# %%
print(training_input_config.config)
print(validation_input_config.config)
# Out:
# {'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3Uri': 's3://udemy-workshop-chloe/wwc-workshop/data/'}}, 'ContentType': 'text/csv'}
# {'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3Uri': 's3://udemy-workshop-chloe/wwc-workshop/validation/'}}, 'ContentType': 'text/csv'}

# %% [markdown]
# # Train the model

# %%
estimator.fit(data_channels)
# Out:
# 2019-11-25 20:32:59 Starting - Starting the training job...
# 2019-11-25 20:33:00 Starting - Launching requested ML instances...
# 2019-11-25 20:33:55 Starting - Preparing the instances for training......
# 2019-11-25 20:34:51 Downloading - Downloading input data...
# 2019-11-25 20:35:24 Training - Downloading the training image...
# 2019-11-25 20:35:56 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# [11/25/2019 20:35:47 INFO 139924829296448] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/25/2019 20:35:47 INFO 139924829296448] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'9', u'mini_batch_size': u'200', u'predictor_type': u'binary_classifier'}
# [11/25/2019 20:35:48 INFO 139924829296448] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'9', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/25/2019 20:35:48 WARNING 139924829296448] Loggers have already been setup.
# Process 1 is a worker.
# [11/25/2019 20:35:48 INFO 139924829296448] Using default worker.
# [11/25/2019 20:35:48 INFO 139924829296448] Create Store: local
# [11/25/2019 20:35:48 INFO 139924829296448] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f42787db310>
# [11/25/2019 20:35:48 INFO 139924829296448] Scaling model computed with parameters:
#  {'stdev_weight':
# [2.7469063 2.9506767 2.8923595 2.8356822 2.2073514 3.604133  2.4278579
#  3.0542746 1.6848145]
# <NDArray 9 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [4.4025 3.0775 3.1475 2.7625 3.24   3.515  3.3975 2.8625 1.58  ]
# <NDArray 9 @cpu(0)>}
# [11/25/2019 20:35:48 INFO 139924829296448] nvidia-smi took: 0.0252070426941 secs to identify 0 gpus
# [11/25/2019 20:35:48 INFO 139924829296448] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Total Records Seen": {"count": 1, "max": 678, "sum": 678.0, "min": 678}, "Max Records Seen Between Resets": {"count": 1, "max": 478, "sum": 478.0, "min": 478}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1574714148.214607, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1574714148.214569}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.
"Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.410789}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": -2.5833156678734754, "sum": -2.5833156678734754, "min": -2.5833156678734754}}, "EndTime": 1574714154.410884, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.410864}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": -2.462712804282584, "sum": -2.462712804282584, "min": -2.462712804282584}}, "EndTime": 1574714154.410949, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.41093}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": -2.5729348531583462, "sum": -2.5729348531583462, "min": -2.5729348531583462}}, "EndTime": 1574714154.411013, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.410994}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": -2.5911541450314406, "sum": -2.5911541450314406, "min": -2.5911541450314406}}, "EndTime": 1574714154.411084, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411065}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.0732836374422399, "sum": 1.0732836374422399, "min": 1.0732836374422399}}, "EndTime": 1574714154.411154, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411135}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8794936761623475, "sum": 0.8794936761623475, "min": 0.8794936761623475}}, "EndTime": 1574714154.411208, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411191}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.030917311877739, "sum": 1.030917311877739, "min": 1.030917311877739}}, "EndTime": 1574714154.411269, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411251}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.1011203393703555, "sum": 1.1011203393703555, "min": 1.1011203393703555}}, "EndTime": 1574714154.411331, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411313}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.9563707863412252, "sum": 0.9563707863412252, "min": 0.9563707863412252}}, "EndTime": 1574714154.411426, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411407}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.9318597095768626, "sum": 0.9318597095768626, "min": 0.9318597095768626}}, "EndTime": 1574714154.411491, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411473}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.943124064003549, "sum": 0.943124064003549, "min": 0.943124064003549}}, "EndTime": 1574714154.411549, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411534}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8728043346870237, "sum": 0.8728043346870237, "min": 0.8728043346870237}}, "EndTime": 1574714154.411602, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411588}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.6216659638939834, "sum": 1.6216659638939834, "min": 1.6216659638939834}}, "EndTime": 1574714154.411653, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.41164}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.6577528232481422, "sum": 1.6577528232481422, "min": 1.6577528232481422}}, "EndTime": 1574714154.411702, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411689}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.6554916381835938, "sum": 1.6554916381835938, "min": 1.6554916381835938}}, "EndTime": 1574714154.411751, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.41174}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.6537034848841226, "sum": 1.6537034848841226, "min": 1.6537034848841226}}, "EndTime": 1574714154.411782, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411774}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.6172224091320504, "sum": 1.6172224091320504, "min": 1.6172224091320504}}, "EndTime": 1574714154.411812, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411804}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.7061053020198171, "sum": 1.7061053020198171, "min": 1.7061053020198171}}, "EndTime": 1574714154.411851, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411842}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.5715488154713702, "sum": 1.5715488154713702, "min": 1.5715488154713702}}, "EndTime": 1574714154.41191, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411896}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 1.6203063220512577, "sum": 1.6203063220512577, "min": 1.6203063220512577}}, "EndTime": 1574714154.41197, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.411958}
#
# [11/25/2019 20:35:54 INFO 139924829296448] #quality_metric: host=algo-1, epoch=14, validation binary_classification_cross_entropy_objective <loss>=0.837857390613
# [11/25/2019 20:35:54 INFO 139924829296448] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=2.0243902439
# [11/25/2019 20:35:54 INFO 139924829296448] Epoch 14: Loss improved. Updating best model
# [11/25/2019 20:35:54 INFO 139924829296448] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 478, "sum": 478.0, "min": 478}, "Total Batches Seen": {"count": 1, "max": 49, "sum": 49.0, "min": 49}, "Total Records Seen": {"count": 1, "max": 7848, "sum": 7848.0, "min": 7848}, "Max Records Seen Between Resets": {"count": 1, "max": 478, "sum": 478.0, "min": 478}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1574714154.413896, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574714154.053274}
#
# [11/25/2019 20:35:54 INFO 139924829296448] #throughput_metric: host=algo-1, train throughput=1324.99557999 records/second
# [11/25/2019 20:35:54 WARNING 139924829296448] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/25/2019 20:35:54 WARNING 139924829296448] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/25/2019 20:35:54 INFO 139924829296448] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=2.0243902439
# [11/25/2019 20:35:54 INFO 139924829296448] Epoch 14: Loss improved. Updating best model
# [11/25/2019 20:35:54 INFO 139924829296448] #validation_score (algo-1) : ('binary_classification_cross_entropy_objective', 1.6577528232481422)
# [11/25/2019 20:35:54 INFO 139924829296448] #validation_score (algo-1) : ('binary_classification_accuracy', 0.4292682926829268)
# [11/25/2019 20:35:54 INFO 139924829296448] #validation_score (algo-1) : ('binary_f_1.000', 1.3712255772646536)
# [11/25/2019 20:35:54 INFO 139924829296448] #validation_score (algo-1) : ('precision', 2.1807909604519775)
# [11/25/2019 20:35:54 INFO 139924829296448] #validation_score (algo-1) : ('recall', 1.0)
# [11/25/2019 20:35:54 INFO 139924829296448] #quality_metric: host=algo-1, validation binary_classification_cross_entropy_objective <loss>=1.65775282325
# [11/25/2019 20:35:54 INFO 139924829296448] #quality_metric: host=algo-1, validation binary_classification_accuracy <score>=0.429268292683
# [11/25/2019 20:35:54 INFO 139924829296448] #quality_metric: host=algo-1, validation binary_f_1.000 <score>=1.37122557726
# [11/25/2019 20:35:54 INFO 139924829296448] #quality_metric: host=algo-1, validation precision <score>=2.18079096045
# [11/25/2019 20:35:54 INFO 139924829296448] #quality_metric: host=algo-1, validation recall <score>=1.0
# [11/25/2019 20:35:54 INFO 139924829296448] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 100, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [11/25/2019 20:35:54 INFO 139924829296448] Saved checkpoint to "/tmp/tmpdA6yaq/mx-mod-0000.params"
# [11/25/2019 20:35:54 INFO 139924829296448] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 6763.561010360718, "sum": 6763.561010360718, "min": 6763.561010360718}, "finalize.time": {"count": 1, "max": 329.01501655578613, "sum": 329.01501655578613, "min": 329.01501655578613}, "initialize.time": {"count": 1, "max": 148.73695373535156, "sum": 148.73695373535156, "min": 148.73695373535156}, "check_early_stopping.time": {"count": 16, "max": 1.3000965118408203, "sum": 16.727924346923828, "min": 0.885009765625}, "setuptime": {"count": 1, "max": 26.500940322875977, "sum": 26.500940322875977, "min": 26.500940322875977}, "update.time": {"count": 15, "max": 525.994062423706, "sum": 6191.72215461731, "min": 353.0888557434082}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1574714154.749874, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1574714148.06562}
# 2019-11-25 20:36:03 Completed - Training job completed
# Training seconds: 72
# Billable seconds: 72

# %% [markdown]
# ## Deploy Model

# %%
predictor = estimator.deploy(initial_instance_count=1,
                             instance_type='ml.m4.xlarge',
                             endpoint_name = 'linear-workshop-v5-1')
# Out:
# -------------------------------------------------------------------------------------!

# %% [markdown]
# ## Run Predictions

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#    diagnosis  clump_thickness  uniformity_of_cell_size  \
# 0          0                5                        1
# 1          0                1                        1
# 2          0                3                        1
# 3          1               10                        5
# 4          0                3                        1
#
#    uniformity_of_cell_shape  marginal_adhesion  single_epithelial_cell_size  \
# 0                         1                  1                            2
# 1                         1                  1                            2
# 2                         1                  1                            2
# 3                         7                  3                            3
# 4                         1                  1                            1
#
#    bare_nuclei     bland_chromatin   normal_nucleoli   mitoses
# 0               1                 2                 1        1
# 1               1                 3                 1        1
# 2               5                 5                 1        1
# 3               7                 3                 3        8
# 4               1                 2                 1        1

# %%
testLabels = test['diagnosis']

# %%
testData = test.iloc[:, 1:]

# %%
testData = testData.to_numpy()

# %%
count =0
for data in testData:
    print(data)
    print("Actual = "+ str(testLabels[count]))
    prediction = predictor.predict(data).decode('utf-8')
    print(prediction)
    count +=1
# Out:
# [5 1 1 1 2 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33217474818229675, "predicted_label": 0.0}]}
# [1 1 1 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3345429301261902, "predicted_label": 1.0}]}
# [3 1 1 1 2 5 5 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3365776836872101, "predicted_label": 1.0}]}
# [10  5  7  3  3  7  3  3  8]
# Actual = 1
# {"predictions": [{"score": 0.33779898285865784, "predicted_label": 1.0}]}
# [3 1 1 1 1 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.332842618227005, "predicted_label": 0.0}]}
# [ 5  5  5  2  5 10  4  3  1]
# Actual = 1
# {"predictions": [{"score": 0.3437749147415161, "predicted_label": 1.0}]}
# [5 1 1 1 2 1 1 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3319191038608551, "predicted_label": 0.0}]}
# [4 1 1 1 2 1 1 2 1]
# Actual = 0
# {"predictions": [{"score": 0.3324126899242401, "predicted_label": 0.0}]}
# [5 2 1 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.333195298910141, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 1 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3340299725532532, "predicted_label": 1.0}]}
# [4 1 2 1 2 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3330024480819702, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3345429301261902, "predicted_label": 1.0}]}
# [8 6 4 3 5 9 3 1 1]
# Actual = 1
# {"predictions": [{"score": 0.34165915846824646, "predicted_label": 1.0}]}
# [3 1 1 2 2 1 1 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3328377902507782, "predicted_label": 0.0}]}
# [10  9  8  7  6  4  7 10  3]
# Actual = 1
# {"predictions": [{"score": 0.34122633934020996, "predicted_label": 1.0}]}
# [3 1 1 3 2 1 1 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3327019214630127, "predicted_label": 0.0}]}
# [1 1 1 3 2 1 1 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3337577283382416, "predicted_label": 1.0}]}
# [ 4  5  5 10  4 10  7  5  8]
# Actual = 1
# {"predictions": [{"score": 0.3427370488643646, "predicted_label": 1.0}]}
# [ 9  9 10  3  6 10  7 10  6]
# Actual = 1
# {"predictions": [{"score": 0.3465036153793335, "predicted_label": 1.0}]}
# [ 7  6  3  2  5 10  7  4  6]
# Actual = 1
# {"predictions": [{"score": 0.34305232763290405, "predicted_label": 1.0}]}
# [ 6 10 10 10  8 10 10 10  7]
# Actual = 1
# {"predictions": [{"score": 0.3493923544883728, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3345429301261902, "predicted_label": 1.0}]}
# [10  5  7  4  4 10  8  9  1]
# Actual = 1
# {"predictions": [{"score": 0.341874361038208, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3342863917350769, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3345429301261902, "predicted_label": 1.0}]}
# [4 2 1 1 2 1 1 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3332110345363617, "predicted_label": 1.0}]}
# [4 1 1 1 2 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33270204067230225, "predicted_label": 0.0}]}
# [10 10 10 10  7 10  7 10  4]
# Actual = 1
# {"predictions": [{"score": 0.34639647603034973, "predicted_label": 1.0}]}
# [4 1 1 1 1 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33231520652770996, "predicted_label": 0.0}]}
# [2 1 2 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3343152105808258, "predicted_label": 1.0}]}
# [5 1 3 3 2 2 2 3 1]
# Actual = 0
# {"predictions": [{"score": 0.33307895064353943, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3345429301261902, "predicted_label": 1.0}]}
# [7 3 4 4 3 3 3 2 7]
# Actual = 1
# {"predictions": [{"score": 0.33437299728393555, "predicted_label": 1.0}]}
# [ 5  6  7  8  8 10  3 10  3]
# Actual = 1
# {"predictions": [{"score": 0.34479060769081116, "predicted_label": 1.0}]}
# [10 10 10  7  9 10  7 10 10]
# Actual = 1
# {"predictions": [{"score": 0.34692278504371643, "predicted_label": 1.0}]}
# [4 1 1 1 2 3 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33398792147636414, "predicted_label": 1.0}]}
# [3 1 2 2 2 1 1 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33313828706741333, "predicted_label": 1.0}]}
# [10  3  3  1  2 10  7  6  1]
# Actual = 1
# {"predictions": [{"score": 0.3385857343673706, "predicted_label": 1.0}]}
# [3 1 1 1 3 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33361709117889404, "predicted_label": 1.0}]}
# [10  6  4  3 10 10  9 10  1]
# Actual = 1
# {"predictions": [{"score": 0.34445664286613464, "predicted_label": 1.0}]}
# [ 8  6  7  3  3 10  3  4  2]
# Actual = 1
# {"predictions": [{"score": 0.3422248661518097, "predicted_label": 1.0}]}
# [ 6  6  6  5  4 10  7  6  2]
# Actual = 1
# {"predictions": [{"score": 0.3440791368484497, "predicted_label": 1.0}]}
# [8 3 3 1 2 2 3 2 1]
# Actual = 0
# {"predictions": [{"score": 0.33358749747276306, "predicted_label": 1.0}]}
# [10  8  4  4  4 10  3 10  4]
# Actual = 1
# {"predictions": [{"score": 0.3416184186935425, "predicted_label": 1.0}]}
# [2 1 1 1 3 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33414551615715027, "predicted_label": 1.0}]}
# [ 7  9  4 10 10  3  5  3  3]
# Actual = 1
# {"predictions": [{"score": 0.3418356478214264, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 2 1 2]
# Actual = 0
# {"predictions": [{"score": 0.3341752290725708, "predicted_label": 1.0}]}
# [3 1 1 1 2 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3332297205924988, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3342863917350769, "predicted_label": 1.0}]}
# [3 2 2 2 2 1 3 2 1]
# Actual = 0
# {"predictions": [{"score": 0.3343832492828369, "predicted_label": 1.0}]}
# [5 2 2 2 2 2 3 2 2]
# Actual = 0
# {"predictions": [{"score": 0.33385851979255676, "predicted_label": 1.0}]}
# [ 8  6  4 10 10  1  3  5  1]
# Actual = 1
# {"predictions": [{"score": 0.33732712268829346, "predicted_label": 1.0}]}
# [1 1 1 2 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3344067335128784, "predicted_label": 1.0}]}
# [ 2  7 10 10  7 10  4  9  4]
# Actual = 1
# {"predictions": [{"score": 0.34761276841163635, "predicted_label": 1.0}]}
# [6 3 3 3 3 2 6 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33556434512138367, "predicted_label": 1.0}]}
# [10  6  3  6  4 10  7  8  4]
# Actual = 1
# {"predictions": [{"score": 0.34059494733810425, "predicted_label": 1.0}]}
# [1 1 1 1 1 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3341550827026367, "predicted_label": 1.0}]}
# [10  8 10  1  3 10  5  1  1]
# Actual = 1
# {"predictions": [{"score": 0.3446323871612549, "predicted_label": 1.0}]}
# [5 1 1 1 2 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33217474818229675, "predicted_label": 0.0}]}
# [3 1 1 1 2 1 2 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3332297205924988, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.3345429301261902, "predicted_label": 1.0}]}
# [10  4  6  4  5 10  7  1  1]
# Actual = 1
# {"predictions": [{"score": 0.3411996066570282, "predicted_label": 1.0}]}
# [1 1 1 1 2 1 3 2 1]
# Actual = 0
# {"predictions": [{"score": 0.33450937271118164, "predicted_label": 1.0}]}
# [3 1 1 1 2 1 3 1 1]
# Actual = 0
# {"predictions": [{"score": 0.333485871553421, "predicted_label": 1.0}]}
# [3 1 1 1 1 1 1 1 1]
# Actual = 0
# {"predictions": [{"score": 0.33258670568466187, "predicted_label": 0.0}]}
# [4 1 1 1 2 1 3 2 1]
# Actual = 0
# {"predictions": [{"score": 0.3329244554042816, "predicted_label": 0.0}]}
# [10  4  4 10  2 10  5  3  3]
# Actual = 1
# {"predictions": [{"score": 0.33778849244117737, "predicted_label": 1.0}]}
# [10 10 10 10 10  1  8  8  8]
# Actual = 1
# {"predictions": [{"score": 0.34157755970954895, "predicted_label": 1.0}]}
# [ 5 10 10  8  5  5  7 10  1]
# Actual = 1
# {"predictions": [{"score": 0.3456386625766754, "predicted_label": 1.0}]}
